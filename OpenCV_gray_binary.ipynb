# %% [markdown]
# <a href="https://colab.research.google.com/github/digregorio/OpenCV_gray_binary/blob/main/OpenCV_gray_binary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# Lê a imagem em formato BGR
img = cv2.imread('/content/pikachu.png')

# Converte a imagem para escala de cinza
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Aplica threshold na imagem para binarizar
thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)[1]

# Exibe as imagens resultantes
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Imagem original')
plt.show()

plt.imshow(gray, cmap='gray')
plt.title('Imagem em escala de cinza')
plt.show()

plt.imshow(thresh, cmap='gray')
plt.title('Imagem binarizada')
plt.show()
